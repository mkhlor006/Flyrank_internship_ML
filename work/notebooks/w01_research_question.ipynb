# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/mkhlor006/Flyrank_internship_ML/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# I chose the content refresh prioritization lane.
# My goal is to identify content pages that may be at higher risk of declining search performance so that they can be reviewed and updated before they lose more traffic.
# I chose this lane because the starter dataset already contains historical performance metrics, and content teams often have limited time to update every page.
# A decision-support model could help prioritize which pages deserve attention first.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# **Decision:**
# Which content pages should be prioritised for review and refreshing?
#
# **Who acts?**
# An SEO specialist or content manager.
#
# **Action:**
# Review the highest-priority pages, update outdated content, improve titles and headings, and optimise pages that appear likely to decline.
#
# **Cost of a wrong recommendation:**
# If the model recommends refreshing a page that does not need attention, time and resources are wasted. If it misses a page that is actually declining, the page may continue losing visibility and traffic before anyone notices.
#
# **Why machine learning can help:**
# The dataset contains several measurable characteristics of pages, such as impressions, click-through rate, average position, content age and update history. These signals may help identify patterns associated with declining performance and support prioritisation decisions.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# The starter dataset contains **30,000** content pages and **44** variables. Among the pages, **16,262** are labelled as having a **downward trend**, making declining performance the largest trend category in the dataset. The average click-through rate (CTR) is **0.51%**, and the average number of impressions over the previous 90 days is **5,200.37**.
#
# These observations suggest that the dataset contains enough variation in page performance to investigate which measurable page characteristics are associated with declining performance. This makes the content refresh prioritization lane a useful problem to explore over the next several weeks.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print(f"Rows: {len(df):,}")
print(f"Columns: {len(df.columns)}")

print("\nTrend direction counts:")
print(df["trend_direction"].value_counts())

print("\nAverage CTR:")
print(round(df["ctr"].mean(), 2))

print("\nAverage impressions (90 days):")
print(round(df["impressions_90d"].mean(), 2))
# Out:
# Rows: 30,000
# Columns: 44
#
# Trend direction counts:
# trend_direction
# down      16262
# stable     5962
# up         4388
# new        2236
# flat       1152
# Name: count, dtype: int64
#
# Average CTR:
# 0.51
#
# Average impressions (90 days):
# 5200.37

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# This project aims to identify observed relationships between measurable page characteristics and declining content performance. The results can support decision-making by helping content teams prioritise which pages to review first.
#
# This project cannot prove that any feature directly causes a page to decline, predict Google's ranking algorithm, or guarantee that refreshing a page will improve its performance. Any findings should be interpreted as observed patterns within this dataset and used as decision-support rather than proof of causation.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
